# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import joblib
import warnings
warnings.simplefilter('ignore')
import os

def rollCollective(district,case='Confirmed'):
    ts=df.loc[(df['District']==district)]  
    ts=ts[['Date',case]]
    ts=ts.set_index('Date')
    ts.astype('int64')
    a=len(ts.loc[(ts['Confirmed']>=10)])
    ts=ts[-a:]
    return (ts.rolling(window=4,center=False).mean().dropna())


def rollPlotCollective(district, case='Confirmed'):
    ts=df.loc[(df['District']==district)]  
    ts=ts[['Date',case]]
    ts=ts.set_index('Date')
    ts.astype('int64')
    a=len(ts.loc[(ts['Confirmed']>=10)])
    ts=ts[-a:]
    plt.figure(figsize=(16,6))
    plt.plot(ts.rolling(window=7,center=False).mean().dropna(),label='Rolling Mean')
    plt.plot(ts[case])
    plt.plot(ts.rolling(window=7,center=False).std(),label='Rolling std')
    plt.legend()
    plt.title('Cases distribution in %s with rolling mean and standard' %district)
    plt.xticks([])
#Function to check the stationarity of the time serie using Dickey fuller test
def stationarity(ts):
    print('Results of Dickey-Fuller Test:')
    test = adfuller(ts, autolag='AIC')
    results = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for i,val in test[4].items():
        results['Critical Value (%s)'%i] = val
    print (results)
def corr(ts):
    plot_acf(ts,lags=12,title="ACF")
    plot_pacf(ts,lags=12,title="PACF")
def mape(y2, y_pred): 
    y2, y_pred = np.array(y2), np.array(y_pred)
    print('\nMean absolute percentage error: %f'%np.mean(np.abs((y2 - y_pred) / y2)) * 100)
    return np.mean(np.abs((y2 - y_pred) / y2)) * 100

#Arima modeling for ts

def arima(tstemp,st,dis):
    p=d=q=range(0,6)
    a=99999
    pdq=set(itertools.product(p,d,q))
    exists=False
    
    #Determining the best parameters
    for var in pdq:
        try:
            model = ARIMA(tstemp, order=var)
            result = model.fit()

            if (result.aic<=a) :
                exists=True
                a=result.aic
                param=var
        except:
            continue
            
    #Modeling
    if exists==True:
        model = ARIMA(tstemp, order=param)
        result = model.fit()

        ##Exporting model
        modelname="arimamodel_for_state_"+st+"_district_"+dis
        print(modelname)
        joblib.dump(model,modelname)

def plotResults(pred,test):
    f,ax=plt.subplots()
    plt.plot(pred,c='green', label= 'predictions')
    plt.plot(test, c='red',label='real values')
    plt.legend()
    plt.title('True vs predicted values')

# %%
list = ['Date', 'State', 'District', 'Confirmed']
df=pd.read_csv('output.csv',usecols=list)

# %%
df
# Out:
#              Date           State          District  Confirmed
# 0      2020-04-26  Andhra Pradesh         Anantapur         53
# 1      2020-04-27  Andhra Pradesh         Anantapur         53
# 2      2020-04-28  Andhra Pradesh         Anantapur         54
# 3      2020-04-29  Andhra Pradesh         Anantapur         58
# 4      2020-04-30  Andhra Pradesh         Anantapur         61
# ...           ...             ...               ...        ...
# 78105  2020-10-01       Meghalaya  South Garo Hills         40
# 78106  2020-10-02       Meghalaya  South Garo Hills         46
# 78107  2020-10-03       Meghalaya  South Garo Hills         46
# 78108  2020-10-04       Meghalaya  South Garo Hills         47
# 78109  2020-10-05       Meghalaya  South Garo Hills         47
#
# [78110 rows x 4 columns]

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
state_dist=set(zip(df['State'],df['District']))

# %%
for [s,d] in state_dist:
    modelname="arimamodel_for_state_"+s+"_district_"+d
    if modelname in os.listdir():
        continue
    else:        
        dftemp=df[df['District']==d]
        train=dftemp[:120]
        test=dftemp[120:]
        train = train.set_index(['Date'])
        test = test.set_index(['Date'])
        traintemp=train['Confirmed'].values
        testtemp=test['Confirmed'].values
        arima(traintemp,s,d)
# Out:
# arimamodel_for_state_Arunachal Pradesh_district_Tawang
# arimamodel_for_state_Karnataka_district_Dharwad
# arimamodel_for_state_West Bengal_district_Uttar Dinajpur
# arimamodel_for_state_Odisha_district_Bargarh
# arimamodel_for_state_Uttarakhand_district_Udham Singh Nagar
# arimamodel_for_state_Mizoram_district_Lunglei
# arimamodel_for_state_Tamil Nadu_district_Namakkal
# arimamodel_for_state_Rajasthan_district_Churu
# arimamodel_for_state_Uttar Pradesh_district_Balrampur
# arimamodel_for_state_Uttar Pradesh_district_Kanpur Nagar
# arimamodel_for_state_Odisha_district_Nuapada
# arimamodel_for_state_Uttar Pradesh_district_Shrawasti
# arimamodel_for_state_Odisha_district_Balangir
# arimamodel_for_state_Madhya Pradesh_district_Jabalpur
# arimamodel_for_state_Uttar Pradesh_district_Varanasi
# arimamodel_for_state_Jammu and Kashmir_district_Kathua
# arimamodel_for_state_Bihar_district_Muzaffarpur
# arimamodel_for_state_Madhya Pradesh_district_Sidhi
# arimamodel_for_state_Tamil Nadu_district_Chennai
# arimamodel_for_state_Mizoram_district_Aizawl
# arimamodel_for_state_Uttarakhand_district_Dehradun
# arimamodel_for_state_Maharashtra_district_Thane
# arimamodel_for_state_Himachal Pradesh_district_Chamba
# arimamodel_for_state_Tamil Nadu_district_Thiruvarur
# arimamodel_for_state_Uttar Pradesh_district_Bareilly
# arimamodel_for_state_Bihar_district_Gopalganj
# arimamodel_for_state_West Bengal_district_Purba Medinipur
# arimamodel_for_state_Bihar_district_Madhepura
# arimamodel_for_state_Uttar Pradesh_district_Firozabad
# arimamodel_for_state_Haryana_district_Jhajjar
# arimamodel_for_state_Himachal Pradesh_district_Shimla
# arimamodel_for_state_Maharashtra_district_Akola
# arimamodel_for_state_Maharashtra_district_Chandrapur
# arimamodel_for_state_Madhya Pradesh_district_Ujjain
# arimamodel_for_state_Punjab_district_Barnala
# arimamodel_for_state_Jharkhand_district_Sahibganj
# arimamodel_for_state_Uttar Pradesh_district_Azamgarh
# arimamodel_for_state_Puducherry_district_Yanam
# arimamodel_for_state_Jharkhand_district_Godda
# arimamodel_for_state_Uttar Pradesh_district_Meerut
# arimamodel_for_state_Bihar_district_Lakhisarai
# arimamodel_for_state_Jharkhand_district_Latehar
# arimamodel_for_state_Andhra Pradesh_district_Anantapur
# arimamodel_for_state_Chandigarh_district_Chandigarh
# arimamodel_for_state_Uttar Pradesh_district_Sultanpur
# arimamodel_for_state_Bihar_district_Jehanabad
# arimamodel_for_state_Kerala_district_Pathanamthitta
# arimamodel_for_state_Rajasthan_district_Pratapgarh
# arimamodel_for_state_Andhra Pradesh_district_Krishna
# arimamodel_for_state_Rajasthan_district_Ganganagar
# arimamodel_for_state_Uttarakhand_district_Almora
# arimamodel_for_state_Uttarakhand_district_Champawat
# arimamodel_for_state_Odisha_district_Puri
# arimamodel_for_state_Rajasthan_district_Bikaner
# arimamodel_for_state_Arunachal Pradesh_district_West Kameng
# arimamodel_for_state_Chhattisgarh_district_Dakshin Bastar Dantewada
# arimamodel_for_state_Jharkhand_district_Giridih
# arimamodel_for_state_Gujarat_district_Jamnagar
# arimamodel_for_state_Jammu and Kashmir_district_Jammu
# arimamodel_for_state_Uttar Pradesh_district_Unnao
# arimamodel_for_state_Andhra Pradesh_district_Vizianagaram
# arimamodel_for_state_Jammu and Kashmir_district_Srinagar
# arimamodel_for_state_Maharashtra_district_Latur
# arimamodel_for_state_Andhra Pradesh_district_West Godavari
# arimamodel_for_state_Tripura_district_Dhalai
# arimamodel_for_state_Meghalaya_district_West Khasi Hills
# arimamodel_for_state_Uttar Pradesh_district_Rae Bareli
# arimamodel_for_state_Bihar_district_Bhagalpur
# arimamodel_for_state_Meghalaya_district_East Garo Hills
# arimamodel_for_state_Jammu and Kashmir_district_Samba
# arimamodel_for_state_Bihar_district_Banka
# arimamodel_for_state_Punjab_district_Patiala
# arimamodel_for_state_Jammu and Kashmir_district_Reasi
# arimamodel_for_state_Punjab_district_Mansa
# arimamodel_for_state_Chhattisgarh_district_Surguja
# arimamodel_for_state_Uttar Pradesh_district_Sant Kabir Nagar
# arimamodel_for_state_Jharkhand_district_Simdega
# arimamodel_for_state_Uttar Pradesh_district_Lalitpur
# arimamodel_for_state_Chhattisgarh_district_Bijapur
# arimamodel_for_state_Madhya Pradesh_district_Bhopal
# arimamodel_for_state_West Bengal_district_Jalpaiguri
# arimamodel_for_state_Rajasthan_district_Sawai Madhopur
# arimamodel_for_state_Jharkhand_district_Lohardaga
# arimamodel_for_state_Bihar_district_Sitamarhi
# arimamodel_for_state_Maharashtra_district_Amravati
# arimamodel_for_state_Gujarat_district_Rajkot
# arimamodel_for_state_Jharkhand_district_Saraikela-Kharsawan
# arimamodel_for_state_Arunachal Pradesh_district_West Siang
# arimamodel_for_state_Rajasthan_district_Sikar
# arimamodel_for_state_Uttarakhand_district_Uttarkashi
# arimamodel_for_state_Gujarat_district_Patan
# arimamodel_for_state_Odisha_district_Kalahandi
# arimamodel_for_state_Madhya Pradesh_district_Shajapur
# arimamodel_for_state_Haryana_district_Rewari
# arimamodel_for_state_Uttar Pradesh_district_Mirzapur
# arimamodel_for_state_Maharashtra_district_Satara
# arimamodel_for_state_Maharashtra_district_Pune
# arimamodel_for_state_Maharashtra_district_Yavatmal
# arimamodel_for_state_Jammu and Kashmir_district_Kishtwar
# arimamodel_for_state_West Bengal_district_Dakshin Dinajpur
# arimamodel_for_state_Chhattisgarh_district_Raigarh
# arimamodel_for_state_Nagaland_district_Kohima
# arimamodel_for_state_Tamil Nadu_district_Perambalur
# arimamodel_for_state_Tamil Nadu_district_Nagapattinam
# arimamodel_for_state_Nagaland_district_Longleng
# arimamodel_for_state_Maharashtra_district_Dhule
# arimamodel_for_state_Madhya Pradesh_district_Barwani
# arimamodel_for_state_Andhra Pradesh_district_Chittoor
# arimamodel_for_state_Tamil Nadu_district_Tiruppur
# arimamodel_for_state_Haryana_district_Mahendragarh
# arimamodel_for_state_Rajasthan_district_Barmer
# arimamodel_for_state_Uttarakhand_district_Bageshwar
# arimamodel_for_state_Tamil Nadu_district_Kancheepuram
# arimamodel_for_state_Tamil Nadu_district_Thanjavur
# arimamodel_for_state_Uttar Pradesh_district_Shahjahanpur
# arimamodel_for_state_Odisha_district_Sambalpur
# arimamodel_for_state_Madhya Pradesh_district_Mandsaur
# arimamodel_for_state_Madhya Pradesh_district_Dewas
# arimamodel_for_state_Punjab_district_Tarn Taran
# arimamodel_for_state_Tamil Nadu_district_Ramanathapuram
# arimamodel_for_state_Odisha_district_Kendrapara
# arimamodel_for_state_Haryana_district_Jind
# arimamodel_for_state_Karnataka_district_Kodagu
# arimamodel_for_state_Uttar Pradesh_district_Bahraich
# arimamodel_for_state_Arunachal Pradesh_district_Upper Subansiri
# arimamodel_for_state_Odisha_district_Jharsuguda
# arimamodel_for_state_Nagaland_district_Tuensang
# arimamodel_for_state_Madhya Pradesh_district_Dindori
# arimamodel_for_state_Tamil Nadu_district_Vellore
# arimamodel_for_state_Madhya Pradesh_district_Mandla
# arimamodel_for_state_Maharashtra_district_Ratnagiri
# arimamodel_for_state_West Bengal_district_Murshidabad
# arimamodel_for_state_Himachal Pradesh_district_Sirmaur
# arimamodel_for_state_Andhra Pradesh_district_East Godavari
# arimamodel_for_state_Uttar Pradesh_district_Siddharthnagar
# arimamodel_for_state_Uttar Pradesh_district_Jaunpur
# arimamodel_for_state_Uttar Pradesh_district_Mathura
# arimamodel_for_state_Arunachal Pradesh_district_Upper Siang
# arimamodel_for_state_Bihar_district_Gaya
# arimamodel_for_state_Andhra Pradesh_district_Kurnool
# arimamodel_for_state_Jharkhand_district_Ramgarh
# arimamodel_for_state_Jammu and Kashmir_district_Anantnag
# arimamodel_for_state_Chhattisgarh_district_Mahasamund
# arimamodel_for_state_Arunachal Pradesh_district_Papum Pare
# arimamodel_for_state_Karnataka_district_Haveri
# arimamodel_for_state_Kerala_district_Palakkad
# arimamodel_for_state_Odisha_district_Sundargarh
# arimamodel_for_state_Rajasthan_district_Karauli
# arimamodel_for_state_Nagaland_district_Kiphire
# arimamodel_for_state_Jammu and Kashmir_district_Punch
# arimamodel_for_state_Karnataka_district_Chitradurga
# arimamodel_for_state_Rajasthan_district_Udaipur
# arimamodel_for_state_Andhra Pradesh_district_Guntur
# arimamodel_for_state_Punjab_district_Fatehgarh Sahib
# arimamodel_for_state_Jharkhand_district_Hazaribagh
# arimamodel_for_state_Jharkhand_district_Khunti
# arimamodel_for_state_Bihar_district_Begusarai
# arimamodel_for_state_Rajasthan_district_Bundi
# arimamodel_for_state_Jharkhand_district_Jamtara
# arimamodel_for_state_Gujarat_district_Bharuch
# arimamodel_for_state_Odisha_district_Nabarangapur
# arimamodel_for_state_Rajasthan_district_Kota
# arimamodel_for_state_Chhattisgarh_district_Uttar Bastar Kanker
# arimamodel_for_state_Uttar Pradesh_district_Kushinagar
# arimamodel_for_state_Karnataka_district_Davanagere
# arimamodel_for_state_Madhya Pradesh_district_Singrauli
# arimamodel_for_state_Bihar_district_Vaishali
# arimamodel_for_state_Gujarat_district_Narmada
# arimamodel_for_state_West Bengal_district_Bankura
# arimamodel_for_state_Bihar_district_Kishanganj
# arimamodel_for_state_Madhya Pradesh_district_Raisen
# arimamodel_for_state_Gujarat_district_Anand
# arimamodel_for_state_Maharashtra_district_Washim
# arimamodel_for_state_Bihar_district_Patna
# arimamodel_for_state_Arunachal Pradesh_district_Lower Subansiri
# arimamodel_for_state_Madhya Pradesh_district_Rajgarh
# arimamodel_for_state_Bihar_district_Bhojpur
# arimamodel_for_state_Uttar Pradesh_district_Ambedkar Nagar
# arimamodel_for_state_Kerala_district_Kannur
# arimamodel_for_state_Puducherry_district_Mahe
# arimamodel_for_state_Kerala_district_Kottayam
# arimamodel_for_state_Rajasthan_district_Nagaur
# arimamodel_for_state_Karnataka_district_Gadag
# arimamodel_for_state_Tamil Nadu_district_Madurai
# arimamodel_for_state_Uttar Pradesh_district_Sitapur
# arimamodel_for_state_Odisha_district_Koraput
# arimamodel_for_state_West Bengal_district_Paschim Medinipur
# arimamodel_for_state_Tamil Nadu_district_Sivaganga

# %%
# Now that the models are generated we can directly load them usin joblib 
# forecast values for give datetime
# compare the forecasted values with a test set in order to generate a mape score and compare with the plot
# Out:
# list
