# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tools.eval_measures import rmse, aic
import warnings
warnings.simplefilter('ignore')

# %%
list = ['Date', 'State', 'District', 'Confirmed','Recovered','Deceased']
df= pd.read_csv('output-Copy1.csv', usecols=list)
df=df.loc[df.District=='Patna',:]
df
# Out:
#             Date  State District  Confirmed  Recovered  Deceased
# 4727  2020-04-26  Bihar    Patna         33          5         0
# 4728  2020-04-27  Bihar    Patna         39          5         0
# 4729  2020-04-28  Bihar    Patna         39          5         0
# 4730  2020-04-29  Bihar    Patna         42          5         0
# 4731  2020-04-30  Bihar    Patna         44          6         0
# ...          ...    ...      ...        ...        ...       ...
# 4885  2020-10-01  Bihar    Patna      28143      25868       213
# 4886  2020-10-02  Bihar    Patna      28382      26070       214
# 4887  2020-10-03  Bihar    Patna      28590      26281       214
# 4888  2020-10-04  Bihar    Patna      28857      26495       215
# 4889  2020-10-05  Bihar    Patna      28857      26495       215
#
# [163 rows x 6 columns]

# %%
df['Date']=pd.to_datetime(df['Date'])
df=df.loc[:,['Date', 'Confirmed','Recovered','Deceased']]

# %%
df['Confirmed logFirst Difference'] = np.log(df['Confirmed']) #- np.log(df['Confirmed'].shift(1))
df['Recovered logFirst Difference'] = np.log(df['Recovered']) #- np.log(df['Recovered'].shift(1))
df['Deceased logFirst Difference'] = np.log(df['Deceased']) #- np.log(df['Deceased'].shift(1))
# df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
# df=df.dropna()

# df
df=df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]
dftemp=df.copy()
df=df.drop(['Confirmed','Recovered','Deceased'],axis=1)

df
# Out:
#            Date  Confirmed logFirst Difference  Recovered logFirst Difference  \
# 4741 2020-05-10                       4.110874                       3.135494
# 4742 2020-05-11                       4.276666                       3.555348
# 4743 2020-05-12                       4.499810                       3.583519
# 4744 2020-05-13                       4.595120                       3.555348
# 4745 2020-05-14                       4.595120                       3.583519
# ...         ...                            ...                            ...
# 4885 2020-10-01                      10.245054                      10.160762
# 4886 2020-10-02                      10.253510                      10.168541
# 4887 2020-10-03                      10.260812                      10.176602
# 4888 2020-10-04                      10.270108                      10.184711
# 4889 2020-10-05                      10.270108                      10.184711
#
#       Deceased logFirst Difference
# 4741                      0.000000
# 4742                      0.000000
# 4743                      0.000000
# 4744                      0.693147
# 4745                      0.693147
# ...                            ...
# 4885                      5.361292
# 4886                      5.365976
# 4887                      5.365976
# 4888                      5.370638
# 4889                      5.370638
#
# [149 rows x 4 columns]

# %%
train=df[:120]
test=df[120:]
testtemp=dftemp[120:]

train = train.set_index(['Date'])
test = test.set_index(['Date'])
testtemp = testtemp.set_index(['Date'])

ts1=train
testFinl=test.copy()
def roll(col):
    ts=ts1.loc[:,[col]]
    ts.astype('int64')
    return (ts.rolling(window=4,center=False).mean().dropna())


def rollPlot(col):
    ts=ts1.loc[:,[col]]
    ts.astype('int64')
    plt.figure(figsize=(16,6))
    plt.plot(ts.rolling(window=4,center=False).mean().dropna(),label='Rolling Mean')
    plt.plot(ts[col])
    plt.plot(ts.rolling(window=4,center=False).std(),label='Rolling std')
    plt.legend()
    plt.title(col+'Cases distribution with rolling mean and standard' )
    plt.xticks([])

# %%
rollPlot('Confirmed logFirst Difference')
rollPlot('Recovered logFirst Difference')
# rollPlot('Deceased logFirst Difference')

# %%
fig=sm.tsa.seasonal_decompose(train.values,freq=4).plot()

# %%
#Function to check the stationarity of the time serie using Dickey fuller test
def stationarity(ts):
    print('Results of Dickey-Fuller Test:')
    test = adfuller(ts, autolag='AIC')
    results = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for i,val in test[4].items():
        results['Critical Value (%s)'%i] = val
    print (results)



tsC2=train['Confirmed logFirst Difference'].values 
tsR2=train['Recovered logFirst Difference'].values 
# tsD2=train['Deceased logFirst Difference'].values 

stationarity(tsC2)
stationarity(tsR2)
stationarity(tsD2)

train
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.929132
# p-value                          0.778228
# #Lags Used                       6.000000
# Number of Observations Used    113.000000
# Critical Value (1%)             -3.489590
# Critical Value (5%)             -2.887477
# Critical Value (10%)            -2.580604
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.638748
# p-value                          0.861984
# #Lags Used                       1.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.590610
# p-value                          0.000134
# #Lags Used                       1.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64
#             Confirmed logFirst Difference  Recovered logFirst Difference  \
# Date
# 2020-05-10                       4.110874                       3.135494
# 2020-05-11                       4.276666                       3.555348
# 2020-05-12                       4.499810                       3.583519
# 2020-05-13                       4.595120                       3.555348
# 2020-05-14                       4.595120                       3.583519
# ...                                   ...                            ...
# 2020-09-02                       9.979244                       9.862978
# 2020-09-03                       9.991178                       9.880117
# 2020-09-04                      10.003152                       9.888272
# 2020-09-05                      10.013149                       9.904737
# 2020-09-06                      10.022736                       9.914180
#
#             Deceased logFirst Difference
# Date
# 2020-05-10                      0.000000
# 2020-05-11                      0.000000
# 2020-05-12                      0.000000
# 2020-05-13                      0.693147
# 2020-05-14                      0.693147
# ...                                  ...
# 2020-09-02                      5.147494
# 2020-09-03                      5.147494
# 2020-09-04                      5.164786
# 2020-09-05                      5.176150
# 2020-09-06                      5.176150
#
# [120 rows x 3 columns]

# %%
def corr(ts):
    plot_acf(ts,lags=12,title="ACF")
    plot_pacf(ts,lags=12,title="PACF")
    

corr(tsC2)
corr(tsR2)
# corr(tsD2)

# %%
model=VAR(train)

# %%
fitted=model.fit(maxlags=12,ic='aic')
fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 25, Nov, 2020
# Time:                     22:57:10
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -16.1889
# Nobs:                     110.000    HQIC:                  -17.5460
# Log likelihood:           640.711    FPE:                9.95704e-09
# AIC:                     -18.4720    Det(Omega_mle):     4.72771e-09
# --------------------------------------------------------------------
# Results for equation Confirmed logFirst Difference
# ====================================================================================================
#                                        coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------
# const                                     0.131131         0.078429            1.672           0.095
# L1.Confirmed logFirst Difference          1.239695         0.102362           12.111           0.000
# L1.Recovered logFirst Difference          0.021436         0.052971            0.405           0.686
# L1.Deceased logFirst Difference           0.152148         0.038443            3.958           0.000
# L2.Confirmed logFirst Difference         -0.141197         0.156595           -0.902           0.367
# L2.Recovered logFirst Difference          0.074045         0.080215            0.923           0.356
# L2.Deceased logFirst Difference          -0.147182         0.055996           -2.628           0.009
# L3.Confirmed logFirst Difference         -0.090224         0.117804           -0.766           0.444
# L3.Recovered logFirst Difference         -0.015296         0.070456           -0.217           0.828
# L3.Deceased logFirst Difference          -0.140844         0.056783           -2.480           0.013
# L4.Confirmed logFirst Difference         -0.195355         0.103310           -1.891           0.059
# L4.Recovered logFirst Difference         -0.116860         0.071089           -1.644           0.100
# L4.Deceased logFirst Difference           0.149690         0.055273            2.708           0.007
# L5.Confirmed logFirst Difference          0.345843         0.104988            3.294           0.001
# L5.Recovered logFirst Difference          0.084108         0.069090            1.217           0.223
# L5.Deceased logFirst Difference           0.080552         0.055827            1.443           0.149
# L6.Confirmed logFirst Difference         -0.086626         0.095924           -0.903           0.366
# L6.Recovered logFirst Difference          0.081900         0.066734            1.227           0.220
# L6.Deceased logFirst Difference          -0.122409         0.054029           -2.266           0.023
# L7.Confirmed logFirst Difference         -0.046285         0.074696           -0.620           0.535
# L7.Recovered logFirst Difference         -0.047402         0.066972           -0.708           0.479
# L7.Deceased logFirst Difference           0.044890         0.055587            0.808           0.419
# L8.Confirmed logFirst Difference         -0.000021         0.073696           -0.000           1.000
# L8.Recovered logFirst Difference         -0.044180         0.065786           -0.672           0.502
# L8.Deceased logFirst Difference           0.051096         0.051518            0.992           0.321
# L9.Confirmed logFirst Difference          0.068865         0.080500            0.855           0.392
# L9.Recovered logFirst Difference         -0.116983         0.068315           -1.712           0.087
# L9.Deceased logFirst Difference          -0.095209         0.051882           -1.835           0.066
# L10.Confirmed logFirst Difference        -0.171126         0.060866           -2.812           0.005
# L10.Recovered logFirst Difference         0.137781         0.043838            3.143           0.002
# L10.Deceased logFirst Difference          0.037871         0.034953            1.083           0.279
# ====================================================================================================
#
# Results for equation Recovered logFirst Difference
# ====================================================================================================
#                                        coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------
# const                                    -0.160916         0.157027           -1.025           0.305
# L1.Confirmed logFirst Difference         -0.387348         0.204944           -1.890           0.059
# L1.Recovered logFirst Difference          1.267822         0.106057           11.954           0.000
# L1.Deceased logFirst Difference           0.069542         0.076968            0.904           0.366
# L2.Confirmed logFirst Difference          0.847303         0.313525            2.703           0.007
# L2.Recovered logFirst Difference         -0.205979         0.160602           -1.283           0.200
# L2.Deceased logFirst Difference          -0.153820         0.112111           -1.372           0.170
# L3.Confirmed logFirst Difference         -0.010946         0.235860           -0.046           0.963
# L3.Recovered logFirst Difference         -0.257293         0.141063           -1.824           0.068
# L3.Deceased logFirst Difference           0.051706         0.113687            0.455           0.649
# L4.Confirmed logFirst Difference         -0.520105         0.206842           -2.515           0.012
# L4.Recovered logFirst Difference          0.187411         0.142331            1.317           0.188
# L4.Deceased logFirst Difference          -0.105891         0.110664           -0.957           0.339
# L5.Confirmed logFirst Difference         -0.092118         0.210201           -0.438           0.661
# L5.Recovered logFirst Difference         -0.190366         0.138329           -1.376           0.169
# L5.Deceased logFirst Difference           0.239766         0.111774            2.145           0.032
# L6.Confirmed logFirst Difference          0.365477         0.192054            1.903           0.057
# L6.Recovered logFirst Difference          0.258889         0.133611            1.938           0.053
# L6.Deceased logFirst Difference          -0.012957         0.108174           -0.120           0.905
# L7.Confirmed logFirst Difference         -0.295898         0.149553           -1.979           0.048
# L7.Recovered logFirst Difference          0.127155         0.134088            0.948           0.343
# L7.Deceased logFirst Difference          -0.258759         0.111293           -2.325           0.020
# L8.Confirmed logFirst Difference          0.677371         0.147551            4.591           0.000
# L8.Recovered logFirst Difference         -0.454275         0.131713           -3.449           0.001
# L8.Deceased logFirst Difference           0.150246         0.103147            1.457           0.145
# L9.Confirmed logFirst Difference         -0.658655         0.161172           -4.087           0.000
# L9.Recovered logFirst Difference          0.145308         0.136777            1.062           0.288
# L9.Deceased logFirst Difference           0.190611         0.103875            1.835           0.067
# L10.Confirmed logFirst Difference         0.177706         0.121862            1.458           0.145
# L10.Recovered logFirst Difference         0.045348         0.087771            0.517           0.605
# L10.Deceased logFirst Difference         -0.193332         0.069981           -2.763           0.006
# ====================================================================================================
#
# Results for equation Deceased logFirst Difference
# ====================================================================================================
#                                        coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------
# const                                    -0.400206         0.226388           -1.768           0.077
# L1.Confirmed logFirst Difference          0.174843         0.295470            0.592           0.554
# L1.Recovered logFirst Difference         -0.174483         0.152903           -1.141           0.254
# L1.Deceased logFirst Difference           1.073777         0.110966            9.677           0.000
# L2.Confirmed logFirst Difference          0.338515         0.452013            0.749           0.454
# L2.Recovered logFirst Difference          0.262452         0.231541            1.133           0.257
# L2.Deceased logFirst Difference           0.097915         0.161632            0.606           0.545
# L3.Confirmed logFirst Difference         -0.092566         0.340042           -0.272           0.785
# L3.Recovered logFirst Difference         -0.136482         0.203372           -0.671           0.502
# L3.Deceased logFirst Difference          -0.151611         0.163904           -0.925           0.355
# L4.Confirmed logFirst Difference         -0.504834         0.298207           -1.693           0.090
# L4.Recovered logFirst Difference          0.139660         0.205200            0.681           0.496
# L4.Deceased logFirst Difference          -0.363875         0.159545           -2.281           0.023
# L5.Confirmed logFirst Difference          0.165283         0.303049            0.545           0.585
# L5.Recovered logFirst Difference         -0.240914         0.199430           -1.208           0.227
# L5.Deceased logFirst Difference           0.135745         0.161146            0.842           0.400
# L6.Confirmed logFirst Difference          0.135746         0.276887            0.490           0.624
# L6.Recovered logFirst Difference          0.052512         0.192629            0.273           0.785
# L6.Deceased logFirst Difference           0.561029         0.155956            3.597           0.000
# L7.Confirmed logFirst Difference         -0.293171         0.215613           -1.360           0.174
# L7.Recovered logFirst Difference         -0.043153         0.193316           -0.223           0.823
# L7.Deceased logFirst Difference          -0.531503         0.160452           -3.313           0.001
# L8.Confirmed logFirst Difference          0.126045         0.212726            0.593           0.554
# L8.Recovered logFirst Difference          0.100727         0.189893            0.530           0.596
# L8.Deceased logFirst Difference           0.213794         0.148708            1.438           0.151
# L9.Confirmed logFirst Difference          0.073788         0.232364            0.318           0.751
# L9.Recovered logFirst Difference          0.004806         0.197193            0.024           0.981
# L9.Deceased logFirst Difference          -0.133246         0.149757           -0.890           0.374
# L10.Confirmed logFirst Difference        -0.028459         0.175690           -0.162           0.871
# L10.Recovered logFirst Difference         0.025433         0.126540            0.201           0.841
# L10.Deceased logFirst Difference          0.007576         0.100893            0.075           0.940
# ====================================================================================================
#
# Correlation matrix of residuals
#                                  Confirmed logFirst Difference  Recovered logFirst Difference  Deceased logFirst Difference
# Confirmed logFirst Difference                         1.000000                       0.218030                      0.028425
# Recovered logFirst Difference                         0.218030                       1.000000                      0.218621
# Deceased logFirst Difference                          0.028425                       0.218621                      1.000000

# %%
# Get the lag order
lag_order = fitted.k_ar

# Input data for forecasting
forecast_input = test.values[-lag_order:]
forecast_input
# #fitted.plot_forecast(start=len(ts), end=len(ts)+len(test))
pred=fitted.forecast(forecast_input ,len(test.dropna()))
test['predictedconfirmedlog']=pred[:,0]
test['predictedConfirmed']=np.exp(pred[:,0])
test['recoveredconfirmedlog']=pred[:,1]
# test['predicted log confri']=pred[:,3]
test
# Out:
#             Confirmed logFirst Difference  Recovered logFirst Difference  \
# Date
# 2020-09-07                      10.033375                       9.923584
# 2020-09-08                      10.042641                       9.942035
# 2020-09-09                      10.051433                       9.948939
# 2020-09-10                      10.060278                       9.959584
# 2020-09-11                      10.069426                       9.978827
# 2020-09-12                      10.078155                       9.986403
# 2020-09-13                      10.085517                       9.998843
# 2020-09-14                      10.093695                      10.009558
# 2020-09-15                      10.101272                      10.015431
# 2020-09-16                      10.110176                      10.022914
# 2020-09-17                      10.121980                      10.034384
# 2020-09-18                      10.130105                      10.046028
# 2020-09-19                      10.140771                      10.054232
# 2020-09-20                      10.149136                      10.061303
# 2020-09-21                      10.159292                      10.068917
# 2020-09-22                      10.167159                      10.075801
# 2020-09-23                      10.175536                      10.087225
# 2020-09-24                      10.182822                      10.092743
# 2020-09-25                      10.193916                      10.106388
# 2020-09-26                      10.203407                      10.115408
# 2020-09-27                      10.213029                      10.124349
# 2020-09-28                      10.220376                      10.133488
# 2020-09-29                      10.227562                      10.145100
# 2020-09-30                      10.235808                      10.155335
# 2020-10-01                      10.245054                      10.160762
# 2020-10-02                      10.253510                      10.168541
# 2020-10-03                      10.260812                      10.176602
# 2020-10-04                      10.270108                      10.184711
# 2020-10-05                      10.270108                      10.184711
#
#             Deceased logFirst Difference  predictedconfirmedlog  \
# Date
# 2020-09-07                      5.176150              10.277434
# 2020-09-08                      5.181784              10.283695
# 2020-09-09                      5.181784              10.288934
# 2020-09-10                      5.214936              10.295120
# 2020-09-11                      5.214936              10.299482
# 2020-09-12                      5.214936              10.303369
# 2020-09-13                      5.236442              10.306681
# 2020-09-14                      5.236442              10.309887
# 2020-09-15                      5.236442              10.312041
# 2020-09-16                      5.257495              10.313232
# 2020-09-17                      5.262690              10.315410
# 2020-09-18                      5.278115              10.317143
# 2020-09-19                      5.278115              10.317125
# 2020-09-20                      5.283204              10.317101
# 2020-09-21                      5.293305              10.316096
# 2020-09-22                      5.298317              10.314280
# 2020-09-23                      5.303305              10.313504
# 2020-09-24                      5.308268              10.311363
# 2020-09-25                      5.313206              10.308479
# 2020-09-26                      5.313206              10.305594
# 2020-09-27                      5.313206              10.301779
# 2020-09-28                      5.332719              10.298028
# 2020-09-29                      5.337538              10.294192
# 2020-09-30                      5.356586              10.289627
# 2020-10-01                      5.361292              10.284818
# 2020-10-02                      5.365976              10.279915
# 2020-10-03                      5.365976              10.274384
# 2020-10-04                      5.370638              10.268837
# 2020-10-05                      5.370638              10.263052
#
#             predictedConfirmed  recoveredconfirmedlog
# Date
# 2020-09-07        29069.182339              10.189377
# 2020-09-08        29251.762970              10.188907
# 2020-09-09        29405.409103              10.185053
# 2020-09-10        29587.874897              10.189119
# 2020-09-11        29717.214420              10.194095
# 2020-09-12        29832.956271              10.197386
# 2020-09-13        29931.942221              10.200992
# 2020-09-14        30028.051521              10.200631
# 2020-09-15        30092.788883              10.201319
# 2020-09-16        30128.663452              10.203568
# 2020-09-17        30194.356537              10.206177
# 2020-09-18        30246.708288              10.209653
# 2020-09-19        30246.183773              10.211651
# 2020-09-20        30245.449637              10.214143
# 2020-09-21        30215.059216              10.215032
# 2020-09-22        30160.253595              10.217326
# 2020-09-23        30136.848887              10.217951
# 2020-09-24        30072.386028              10.219165
# 2020-09-25        29985.792296              10.220231
# 2020-09-26        29899.417847              10.221224
# 2020-09-27        29785.573804              10.220500
# 2020-09-28        29674.037655              10.219433
# 2020-09-29        29560.434324              10.217544
# 2020-09-30        29425.789094              10.215226
# 2020-10-01        29284.632551              10.213334
# 2020-10-02        29141.387636              10.210912
# 2020-10-03        28980.656750              10.207384
# 2020-10-04        28820.335737              10.203184
# 2020-10-05        28654.100614              10.198220

# %%
def mape(y2, y_pred): 
    y2, y_pred = np.array(y2), np.array(y_pred)
    return np.mean(np.abs((y2 - y_pred) / y2)) * 100
# # Get the lag order
# lag_order = fitted.k_ar

# # Input data for forecasting
# forecast_input = testFinl.values[-lag_order:]
# forecast_input
# # #fitted.plot_forecast(start=len(ts), end=len(ts)+len(test))
# pred=fitted.forecast(forecast_input ,80)

# #Plotting results
f,ax=plt.subplots()
plt.plot(test['predictedconfirmedlog'],c='green', label= 'predictions')
plt.plot(test['Confirmed logFirst Difference'], c='red',label='real values')
plt.legend()
plt.title('True vs predicted values')
print('\nMean absolute percentage error: %f'%mape(test['Confirmed logFirst Difference'],test['predictedconfirmedlog']))
# pred
# Out:
# Mean absolute percentage error: 1.414811

# %%
##add granger causality and corr function
## run model for all districts
## calculate cumulative aerage mape score
